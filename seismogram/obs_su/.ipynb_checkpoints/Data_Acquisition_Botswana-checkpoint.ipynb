# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pylab as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 15, 4
plt.rcParams['lines.linewidth'] = 0.5

# %%
#2017-4-3T17:40:18
t = UTCDateTime(2017, 4, 3, 17, 40, 18)
lon = 25.1558
lat = -22.6784

client = Client("IRIS")
inventory = client.get_stations(
    starttime=t-180, endtime=t+180,
    longitude=lon, latitude=lat, maxradius=10,
    matchtimeseries=None)
print(inventory)
# Out:
# Inventory created at 2022-05-11T23:22:09.514000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.48
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2017-04-03...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (8):
# 			8A, AF, GE, GT, IU, NR, SY, ZT
# 		Stations (180):
# 			8A.BAHE (Namibia)
# 			8A.GAMM (Namibia)
# 			8A.HELM (Namibia)
# 			8A.HOCH (Namibia)
# 			8A.KANO (Namibia)
# 			8A.NEPA (Namibia)
# 			8A.OKAM (Namibia)
# 			8A.OMUT (Namibia)
# 			8A.OTJO (Namibia)
# 			8A.WEWE (Namibia)
# 			AF.BLWY (Bulawayo, Zimbabwe)
# 			AF.CNG (Changalane Maputo Province Mozambique)
# 			AF.CRLN (Carolina, Mapumpalanga, South Africa)
# 			AF.HVD (Gariep Dam CMG-40T Earth data Low gain)
# 			AF.MONG (Mongu, Zambia, Africa)
# 			AF.MOPA (Mopani Camp, Kruger National Park, RSA)
# 			AF.MUSN (Musina, Limpopo, South Africa)
# 			AF.PKA (Prieska CMG-40T Earth data Low gain)
# 			AF.POGA (Pongola, Kwazulu-Natal, South Africa)
# 			AF.RUDU (Rundu, Ovamboland, Namibia)
# 			AF.SNKL (Senekal, Freestate Province, South Africa)
# 			AF.SWZ (Schweizer Reneke CMG-40T Earth data Low gain)
# 			AF.TEZI (Itezhi-tezhi, Zambia)
# 			AF.UPI (Upington KS2000 Earth data Low gain)
# 			AF.WDLM (Western deep levels CMG-3T Earth data Low gain)
# 			AF.WIN (Windhoek, Namibia)
# 			GE.WIN (GSN/GEOFON Station Windhoek, Namibia)
# 			GT.BOSA (Boshof, South Africa)
# 			GT.LBTB (Lobatse, Botswana)
# 			IU.LSZ (Lusaka, Zambia)
# 			IU.TSUM (Tsumeb, Namibia)
# 			NR.NE201 (Sekoma)
# 			NR.NE202 (Lokgwabe)
# 			NR.NE203 (Kole)
# 			NR.NE204 (Xaudum)
# 			NR.NE205 (Selinda)
# 			NR.NE206 (Kasane)
# 			NR.NE207 (Qangwa)
# 			NR.NE208 (Khwee)
# 			NR.NE209 (CKGR)
# 			NR.NE210 (Groot Laagt)
# 			NR.NE211 (Kacgae)
# 			NR.NE212 (Kaudwane)
# 			NR.NE213 (Phepheng)
# 			NR.NE214 (Gumare)
# 			NR.NE215 (Bottlepan)
# 			NR.NE216 (Phuduhudu)
# 			NR.NE217 (Borolong)
# 			NR.NE218 (Sowa)
# 			NR.NE219 (Moremi)
# 			NR.NE220 (Lephepe)
# 			NR.NE221 (Mmakgori)
# 			SY.AIAI (AIAI synthetic)
# 			SY.ALKP (ALKP synthetic)
# 			SY.AROB (AROB synthetic)
# 			SY.ARON (ARON synthetic)
# 			SY.AUG (AUG synthetic)
# 			SY.BAHE (BAHE synthetic)
# 			SY.BANH (BANH synthetic)
# 			SY.BLWY (BLWY synthetic)
# 			SY.BOSA (BOSA synthetic)
# 			SY.BROLN (BROLN synthetic)
# 			SY.BTLPN (BTLPN synthetic)
# 			SY.CATA (CATA synthetic)
# 			SY.CATB (CATB synthetic)
# 			SY.CHIB (CHIB synthetic)
# 			SY.CHID (CHID synthetic)
# 			SY.CHIT (CHIT synthetic)
# 			SY.CHOK (CHOK synthetic)
# 			SY.CKGRV (CKGRV synthetic)
# 			SY.CNG (CNG synthetic)
# 			SY.CRLN (CRLN synthetic)
# 			SY.ESPU (ESPU synthetic)
# 			SY.FUNH (FUNH synthetic)
# 			SY.GAMM (GAMM synthetic)
# 			SY.GMARE (GMARE synthetic)
# 			SY.GRTLG (GRTLG synthetic)
# 			SY.GSN (GSN synthetic)
# 			SY.GUGU (GUGU synthetic)
# 			SY.HARE (HARE synthetic)
# 			SY.HELM (HELM synthetic)
# 			SY.HOCH (HOCH synthetic)
# 			SY.HOMO (HOMO synthetic)
# 			SY.HVD (HVD synthetic)
# 			SY.INCA (INCA synthetic)
# 			SY.INCB (INCB synthetic)
# 			SY.KANO (KANO synthetic)
# 			SY.KDWAN (KDWAN synthetic)
# 			SY.KEIM (KEIM synthetic)
# 			SY.KETS (KETS synthetic)
# 			SY.KGCAE (KGCAE synthetic)
# 			SY.KHWEE (KHWEE synthetic)
# 			SY.KOMG (KOMG synthetic)
# 			SY.KOOLE (KOOLE synthetic)
# 			SY.KSANE (KSANE synthetic)
# 			SY.KSD (KSD synthetic)
# 			SY.LBTB (LBTB synthetic)
# 			SY.LKGWB (LKGWB synthetic)
# 			SY.LPHEP (LPHEP synthetic)
# 			SY.LSZ (LSZ synthetic)
# 			SY.MABO (MABO synthetic)
# 			SY.MACO (MACO synthetic)
# 			SY.MAFA (MAFA synthetic)
# 			SY.MAKGR (MAKGR synthetic)
# 			SY.MAMB (MAMB synthetic)
# 			SY.MANI (MANI synthetic)
# 			SY.MARI (MARI synthetic)
# 			SY.MONG (MONG synthetic)
# 			SY.MOPA (MOPA synthetic)
# 			SY.MREMI (MREMI synthetic)
# 			SY.MSNA (MSNA synthetic)
# 			SY.MUAN (MUAN synthetic)
# 			SY.MUSN (MUSN synthetic)
# 			SY.MUXU (MUXU synthetic)
# 			SY.NE201 (NE201 synthetic)
# 			SY.NE202 (NE202 synthetic)
# 			SY.NE203 (NE203 synthetic)
# 			SY.NE204 (NE204 synthetic)
# 			SY.NE205 (NE205 synthetic)
# 			SY.NE206 (NE206 synthetic)
# 			SY.NE207 (NE207 synthetic)
# 			SY.NE208 (NE208 synthetic)
# 			SY.NE209 (NE209 synthetic)
# 			SY.NE210 (NE210 synthetic)
# 			SY.NE211 (NE211 synthetic)
# 			SY.NE212 (NE212 synthetic)
# 			SY.NE213 (NE213 synthetic)
# 			SY.NE214 (NE214 synthetic)
# 			SY.NE215 (NE215 synthetic)
# 			SY.NE216 (NE216 synthetic)
# 			SY.NE217 (NE217 synthetic)
# 			SY.NE218 (NE218 synthetic)
# 			SY.NE219 (NE219 synthetic)
# 			SY.NE220 (NE220 synthetic)
# 			SY.NE221 (NE221 synthetic)
# 			SY.NEPA (NEPA synthetic)
# 			SY.NHAN (NHAN synthetic)
# 			SY.OKAM (OKAM synthetic)
# 			SY.OMUT (OMUT synthetic)
# 			SY.ORPN (ORPN synthetic)
# 			SY.OTJO (OTJO synthetic)
# 			SY.PHDHD (PHDHD synthetic)
# 			SY.PHPEN (PHPEN synthetic)
# 			SY.PKA (PKA synthetic)
# 			SY.PNDA (PNDA synthetic)
# 			SY.PNG (PNG synthetic)
# 			SY.POGA (POGA synthetic)
# 			SY.PRYS (PRYS synthetic)
# 			SY.QNGWA (QNGWA synthetic)
# 			SY.RUDU (RUDU synthetic)
# 			SY.SCHUN (SCHUN synthetic)
# 			SY.SEK (SEK synthetic)
# 			SY.SGOR (SGOR synthetic)
# 			SY.SIRH (SIRH synthetic)
# 			SY.SKOMA (SKOMA synthetic)
# 			SY.SLIND (SLIND synthetic)
# 			SY.SNKL (SNKL synthetic)
# 			SY.SOLI (SOLI synthetic)
# 			SY.SOOWA (SOOWA synthetic)
# 			SY.SUSS (SUSS synthetic)
# 			SY.SWZ (SWZ synthetic)
# 			SY.TEZI (TEZI synthetic)
# 			SY.TSUM (TSUM synthetic)
# 			SY.UPI (UPI synthetic)
# 			SY.WAND (WAND synthetic)
# 			SY.WDL (WDL synthetic)
# 			SY.WDLM (WDLM synthetic)
# 			SY.WEWE (WEWE synthetic)
# 			SY.WIN (WIN synthetic)
# 			SY.XAUDM (XAUDM synthetic)
# 			SY.ZINA (ZINA synthetic)
# 			ZT.HOED (Raptors View, Hoedspruit, South Africa)
# 			ZT.LESE (Lesego, Limpopo, South Africa)
# 			ZT.MARA (Verloren, Limpopo, South Africa)
# 			ZT.MARK (Marken, Limpopo, South Africa)
# 			ZT.MRCO (Great Marico, North-West Province, South AFrica)
# 			ZT.NHAM (Northam, Limpopo Province, South Africa)
# 			ZT.NYAT (Nyati, North-West Province, South Africa)
# 			ZT.NYLS (Nylsvlei, Limpopo, South Africa)
# 			ZT.VERL (Verloren, Limpopo, South Africa)
# 		Channels (0):

# %%
station_list = ["NE208", "NE211","NE212","NE216"]

# %%
for sta in station_list:
    print(sta)
# Out:
# NE208
# NE211
# NE212
# NE216

# %%
for sta in station_list:
#sta = 'NE211'
    st = client.get_waveforms("NR", sta, "", "BH?", t-20, t+180)
    st.plot();#Plot RAW data
    inv = client.get_stations(network="NR", station=sta, location="", channel="BH?",
                     starttime=t-20, endtime=t+160, level="response")
    #instrument removed + filter + DISP
    st.slice(endtime=t+180).copy().remove_response(inventory=inv, output="DISP").taper(0.05).filter("bandpass", 
    freqmin=0.2, freqmax=0.6, corners=4).plot();

# %%
for sta in station_list:
    st = client.get_waveforms("NR", sta, "", "BH?", t-20, t+180)
    st.plot();#Plot RAW data
    inv = client.get_stations(network="NR", station=sta, location="", channel="BH?",
                     starttime=t-20, endtime=t+160, level="response")
    #instrument removed + filter + VEL
    st.slice(endtime=t+180).copy().remove_response(inventory=inv, output="VEL").taper(0.05).filter("bandpass", 
    freqmin=0.2, freqmax=0.6, corners=4).plot();
