# %%
from obspy import read
import os

# %%
#Data request through IRIS DMC
#http://ftp.iris.edu/wilber3/find_stations/10046663
#BH? HH? EH?; 
#Distance range: 4 degree > 23 stations
#22.6784° S 25.1558° E 2017-04-03 17:40:18 UTC 29.0 km Mww6.5

# %%
current_path = os.getcwd()
print(current_path)
# Out:
# /Users/hongyisu/Desktop/masterthesis/seismogram/obs_su

# %%
st = read(str(current_path) + "/2017-04-03-mww65-botswana-event-time/NR.NE202..BHE.M.2017.093.173918.SAC", debug_headers=True)

# %%
st
# Out:
# 1 Trace(s) in Stream:
# NR.NE202..BHE | 2017-04-03T17:39:18.005300Z - 2017-04-03T17:50:17.955300Z | 20.0 Hz, 13200 samples

# %%
st.plot();
